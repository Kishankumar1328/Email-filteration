# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishankumar1328/Email-filteration/blob/main/Mail_Filteration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


df = pd.DataFrame({
    'user_id': [1, 2, 3, 4, 5, 6, 7,16,29],
    'name': ['Winston', 'Jonathan', 'Annabelle', 'Sally', 'Marwan', 'David', 'Shapiro',"james","kiruthik"],
    'mail': ['winston@gmail.com', 'jonathanisgreat', 'bella-@gmail.com', 'sally.come@gmail.com', 'quarz#2020@gmail.com', 'david69@gmail.com', '.shapo@hotmail.com','kk1329@outlook.com','kirthik13@hotmail.com']
}
)

df
# Out:
#    user_id       name                   mail
# 0        1    Winston      winston@gmail.com
# 1        2   Jonathan        jonathanisgreat
# 2        3  Annabelle       bella-@gmail.com
# 3        4      Sally   sally.come@gmail.com
# 4        5     Marwan   quarz#2020@gmail.com
# 5        6      David      david69@gmail.com
# 6        7    Shapiro     .shapo@hotmail.com
# 7       16      james     kk1329@outlook.com
# 8       29   kiruthik  kirthik13@hotmail.com

# %%
df[df["mail"].str.match(r'[a-zA-Z][a-zA-Z\d_.-]*@gmail(\?com)?\.com$')]
# Out:
#    user_id       name                  mail
# 0        1    Winston     winston@gmail.com
# 2        3  Annabelle      bella-@gmail.com
# 3        4      Sally  sally.come@gmail.com
# 5        6      David     david69@gmail.com

# %%
df[df["mail"].str.match(r'[a-zA-Z][a-zA-Z\d_.-]*@outlook(\?com)?\.com$')]
# Out:
#    user_id   name                mail
# 7       16  james  kk1329@outlook.com

# %%
df[df["mail"].str.match(r'[a-zA-Z][a-zA-Z\d_.-]*@hotmail(\?com)?\.com$')]
# Out:
#    user_id      name                   mail
# 8       29  kiruthik  kirthik13@hotmail.com
